# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/train.csv", index_col = 0)
df.head()
# Out:
#     carat        cut color clarity  depth  table     x     y     z  price
# id
# 0    0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1    1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
# 2    0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54  7.983
# 3    1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12  8.371
# 4    0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82  6.588

# %%
df.shape
# Out:
# (40455, 10)

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %% [markdown]
# Creo una nueva variable que suponga el volumen total del diamante, calculada a partir de la multiplicación de sus tres dimensiones.

# %%
df['size'] = df['x'] * df['y'] * df['z']

# %%
df.head()
# Out:
#     carat        cut color clarity  depth  table     x     y     z  price  \
# id
# 0    0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1    1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
# 2    0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54  7.983
# 3    1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12  8.371
# 4    0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82  6.588
#
#           size
# id
# 0    49.437424
# 1   167.551728
# 2   116.024916
# 3   175.141200
# 4    57.739500

# %% [markdown]
# Calculo nuevamente depth, pues en el csv aportado los datos no son exactos.

# %%
df['depthcalc'] = df['z'] / ((df['x'] + df['y'])/2)

# %%
df.head()
# Out:
#     carat        cut color clarity  depth  table     x     y     z  price  \
# id
# 0    0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1    1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
# 2    0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54  7.983
# 3    1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12  8.371
# 4    0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82  6.588
#
#           size  depthcalc
# id
# 0    49.437424   0.623981
# 1   167.551728   0.627329
# 2   116.024916   0.618341
# 3   175.141200   0.631902
# 4    57.739500   0.623204

# %%
df.select_dtypes(include=np.number).describe().T
# Out:
#              count        mean        std     min        25%         50%  \
# carat      40455.0    0.797576   0.475939   0.200   0.400000    0.700000
# depth      40455.0   61.746377   1.436796  43.000  61.000000   61.800000
# table      40455.0   57.451694   2.234569  44.000  56.000000   57.000000
# x          40455.0    5.729163   1.125244   0.000   4.710000    5.690000
# y          40455.0    5.732896   1.154799   0.000   4.720000    5.700000
# z          40455.0    3.537351   0.711002   0.000   2.910000    3.520000
# price      40455.0    7.783822   1.016828   5.787   6.851000    7.780000
# size       40455.0  129.820696  79.136536   0.000  64.913352  114.608208
# depthcalc  40449.0    0.617430   0.033095   0.000   0.610402    0.618366
#
#                   75%          max
# carat        1.040000     5.010000
# depth       62.500000    79.000000
# table       59.000000    95.000000
# x            6.540000    10.740000
# y            6.540000    58.900000
# ...

# %%
plt.figure(figsize = (10,5))

sns.heatmap(df.corr(),
            cmap = "YlGnBu",
           annot = True)

plt.title('Correlación entre variables');

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(30, 10)) 
lista_colores = ['blue', 'green', 'red', 'cyan', 'magenta', 'orange', 'blue', 'red']
axes = axes.flat

columnas_numeric = df.select_dtypes(include= np.number).columns
columnas_numeric = columnas_numeric.drop('price')

for i, colum in enumerate(columnas_numeric):
    sns.histplot(
        data    = df,
        x       = colum,
        kde     = True,
        color   = lista_colores[i],
        line_kws= {'linewidth': 2},
        alpha   = 0.2,
        ax      = axes[i]
    )
    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")
    
    
fig.tight_layout()
plt.subplots_adjust(top = 0.9)
plt.tight_layout()
fig.suptitle('Distribución variables numéricas', fontsize = 20, fontweight = "bold");

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(15, 5))

axes = axes.flat

columnas_numeric = df.select_dtypes(include=['float64', 'int']).columns
columnas_numeric = columnas_numeric.drop('price')


for i, colum in enumerate(columnas_numeric):
    sns.regplot(
        x           = df[colum],
        y           = df['price'],
        color       = "gray",
        marker      = '.',
        scatter_kws = {"alpha":0.4},
        line_kws    = {"color":"r","alpha":0.7},
        ax          = axes[i]
    )
    axes[i].set_title(f"precio vs {colum}", fontsize = 8, fontweight = "bold")
    axes[i].tick_params(labelsize = 9)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")

    
fig.tight_layout() 
plt.subplots_adjust(top = 0.9) 
plt.tight_layout()
fig.suptitle('Correlación con precio', fontsize = 10, fontweight = "bold");

# %%
df.drop(columns = ['x', 'y', 'z', 'depthcalc', 'depth', 'table'], inplace = True)
df.head()
# Out:
#     carat        cut color clarity  price        size
# id
# 0    0.30    Premium     D     SI2  6.353   49.437424
# 1    1.01      Ideal     E    VVS2  9.183  167.551728
# 2    0.72      Ideal     F     VS2  7.983  116.024916
# 3    1.08  Very Good     G     SI2  8.371  175.141200
# 4    0.36    Premium     G     VS1  6.588   57.739500

# %%
df.head()
# Out:
#     carat        cut color clarity  price        size
# id
# 0    0.30    Premium     D     SI2  6.353   49.437424
# 1    1.01      Ideal     E    VVS2  9.183  167.551728
# 2    0.72      Ideal     F     VS2  7.983  116.024916
# 3    1.08  Very Good     G     SI2  8.371  175.141200
# 4    0.36    Premium     G     VS1  6.588   57.739500

# %%
df.to_csv('../data/dflimpio.csv')
