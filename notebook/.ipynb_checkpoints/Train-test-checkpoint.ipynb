# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("../data/dfperf.csv", index_col = 0)
df.head()
# Out:
#     carat  cut  color  clarity  price        size
# id
# 0    0.30    4      6        1  6.353   49.437424
# 1    1.01    3      5        5  9.183  167.551728
# 2    0.72    3      4        3  7.983  116.024916
# 3    1.08    2      3        1  8.371  175.141200
# 4    0.36    4      3        4  6.588   57.739500

# %%
df.describe().T.head()
# Out:
#            count      mean       std    min    25%    50%    75%    max
# carat    40396.0  0.794495  0.468762  0.200  0.400  0.700  1.040  2.720
# cut      40396.0  2.700837  1.151197  0.000  2.000  3.000  4.000  4.000
# color    40396.0  3.410610  1.702246  0.000  2.000  3.000  5.000  6.000
# clarity  40396.0  3.051688  1.644971  0.000  2.000  3.000  4.000  7.000
# price    40396.0  7.781305  1.015292  5.787  6.851  7.777  8.577  9.842

# %%
y = df["price"]
X = df.drop(columns=["price"])

# %%
pipe = Pipeline(steps=[('estimator', LinearRegression())])

# %%
params_grid = [{
                'estimator':[LinearRegression()],
                },
                {
                'estimator': [DecisionTreeRegressor()],
                'estimator__max_depth': [4, 5, 6, 7],
                'estimator__max_features': ["sqrt", "log2"],
                'estimator__min_samples_split': [10, 50, 100], 
                'estimator__min_samples_leaf':[1,2,3],
                },
                {'estimator':[RandomForestRegressor()],
                 'estimator__n_estimators':[50,100,200,300],
                 'estimator__max_depth':[4, 5, 6, 7], 
                 'estimator__min_samples_split':[2,3], 
                 'estimator__min_samples_leaf':[1,2,3],
                },
                {'estimator':[KNeighborsRegressor()],
                 'estimator__n_neighbors':[3,5,6,7, 8, 9, 10],
                }

              ]

# %%
grid = GridSearchCV(pipe, params_grid, n_jobs= -1, verbose = 3)

# %%
# %%time
res = grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 176 candidates, totalling 880 fits
# Wall time: 16min 58s

# %%
best_model = grid.best_params_
best_model
# Out:
# {'estimator': KNeighborsRegressor(n_neighbors=8), 'estimator__n_neighbors': 8}

# %%
results = pd.DataFrame(grid.cv_results_).head()
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.056567      0.002652         0.018790    7.853646e-03
# 1       0.125527      0.019282         0.012993    6.330131e-04
# 2       0.117731      0.023307         0.011994    8.926051e-04
# 3       0.118932      0.015431         0.010794    7.481118e-04
# 4       0.120331      0.022443         0.010994    5.309834e-07
#
#            param_estimator param_estimator__max_depth  \
# 0       LinearRegression()                        NaN
# 1  DecisionTreeRegressor()                          4
# 2  DecisionTreeRegressor()                          4
# 3  DecisionTreeRegressor()                          4
# 4  DecisionTreeRegressor()                          4
#
#   param_estimator__max_features param_estimator__min_samples_leaf  \
# 0                           NaN                               NaN
# 1                          sqrt                                 1
# 2                          sqrt                                 1
# 3                          sqrt                                 1
# 4                          sqrt                                 2
#
#   param_estimator__min_samples_split param_estimator__n_estimators  \
# 0                                NaN                           NaN
# 1                                 10                           NaN
# 2                                 50                           NaN
# 3                                100                           NaN
# 4                                 10                           NaN
#
#   param_estimator__n_neighbors  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                               params  split0_test_score  \
# 0                  {'estimator': LinearRegression()}           0.890025
# 1  {'estimator': DecisionTreeRegressor(), 'estima...           0.887543
# 2  {'estimator': DecisionTreeRegressor(), 'estima...           0.939601
# 3  {'estimator': DecisionTreeRegressor(), 'estima...           0.930833
# 4  {'estimator': DecisionTreeRegressor(), 'estima...           0.907609
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.888411           0.890612           0.892459           0.887688
# 1           0.925090           0.937438           0.862584           0.934113
# 2           0.929932           0.810047           0.937023           0.828370
# 3           0.929614           0.907237           0.941916           0.934406
# 4           0.905470           0.932391           0.930550           0.937093
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.889839        0.001683              174
# 1         0.909354        0.029368              171
# 2         0.888995        0.057362              176
# 3         0.928801        0.011603              160
# 4         0.922622        0.013321              164

# %%
results = cross_validate(estimator=KNeighborsRegressor(n_neighbors=8), 
               X=X, y=y, scoring='neg_root_mean_squared_error', cv=10, verbose = 3,  n_jobs= -1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.8s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.3s finished

# %%
rmse_ = abs(results["test_score"].mean())
rmse_
# Out:
# 0.12453347491707267
